# %%
import pandas as pd
import numpy as np
dataframe=pd.read_csv('pandas_tutorial_read.csv', sep=';')
dataframe
# Out:
#       2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 0     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 1     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 2     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 3     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 4     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 5     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 6     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 7     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 8     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 9     2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# 10    2018-01-01 00:08:57  read  country_7  2458151272      SEO      Australia
# ...

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\rajeshkc'

# %%
os.chdir('coursera')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rajeshkc\\coursera'

# %%
os.chdir('week2')

# %%
dataframe=pd.read_csv('pandas_tutorial_read.csv', sep=';',names=['my_datatime','event','country','user_id','source','topic'])
dataframe.head()
# Out:
#            my_datatime event    country     user_id   source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America

# %%
dataframe[['country','user_id']].head() # just to print country and user id column only
#the outer bracket frames tell pandas that you want to select columns, and the inner brackets are for the list 
#(remember? Python lists go between bracket frames) of the column names.
# Out:
#      country     user_id
# 0  country_7  2458151261
# 1  country_7  2458151262
# 2  country_7  2458151263
# 3  country_7  2458151264
# 4  country_8  2458151265

# %%
dataframe['country'].head()# print coulmn series
# Out:
# 0    country_7
# 1    country_7
# 2    country_7
# 3    country_7
# 4    country_8
# Name: country, dtype: object

# %%
dataframe[['user_id','country']].head() # order of columns  can be changed by changing the order
# Out:
#       user_id    country
# 0  2458151261  country_7
# 1  2458151262  country_7
# 2  2458151263  country_7
# 3  2458151264  country_7
# 4  2458151265  country_8

# %%
dataframe[dataframe['source'] == 'SEO'].head()
# Out:
#             my_datatime event    country     user_id source          topic
# 0   2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1   2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America
# 11  2018-01-01 00:08:57  read  country_7  2458151272    SEO      Australia
# 15  2018-01-01 00:11:22  read  country_7  2458151276    SEO  North America
# 16  2018-01-01 00:13:05  read  country_8  2458151277    SEO  North America

# %%
dataframe['source'] == 'SEO'
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12      False
# 13      False
# 14      False
# 15       True
# 16       True
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26       True
# 27       True
# 28      False
# 29      False
#         ...
# 1765    False
# 1766    False
# 1767    False
# 1768    False
# 1769    False
# 1770    False
# 1771    False
# 1772     True
# 1773    False
# 1774    False
# 1775    False
# 1776    False
# 1777     True
# 1778    False
# 1779     True
# 1780    False
# 1781    False
# 1782    False
# 1783    False
# 1784     True
# 1785    False
# 1786    False
# 1787    False
# 1788    False
# 1789    False
# 1790    False
# 1791     True
# 1792    False
# 1793    False
# 1794    False
# ...

# %% [markdown]
# Select the user_id, the country and the topic columns for the users who are from country_2! Print the first five rows only!

# %%
dataframe[dataframe.country == 'country_2'].drop(['my_datatime','event','source'], axis=1).head()
# Out:
#       country     user_id   topic
# 6   country_2  2458151267  Europe
# 13  country_2  2458151274  Europe
# 17  country_2  2458151278    Asia
# 19  country_2  2458151280    Asia
# 20  country_2  2458151281    Asia

# %%
dataframe[dataframe.country=='country_2'][['user_id','topic','country']].head()
# Out:
#        user_id   topic    country
# 6   2458151267  Europe  country_2
# 13  2458151274  Europe  country_2
# 17  2458151278    Asia  country_2
# 19  2458151280    Asia  country_2
# 20  2458151281    Asia  country_2

# %% [markdown]
# Data aggregation

# %%
import pandas as pd
import numpy as np
dataframe2=pd.read_csv('zoo.csv') 
dataframe2
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %% [markdown]
# Okay, let’s do five things with this data:
#
# Let’s count the number of rows (the number of animals) in zoo!
# Let’s calculate the total water_need of the animals!
# Let’s find out which is the smallest water_need value!
# And then the greatest water_need value!
# And eventually the average water_need!

# %%
len(dataframe2.animal) #the number of rows
# Out:
# 22

# %%
dataframe2.count() #finding number of elements
# Out:
# animal        22
# uniq_id       22
# water_need    22
# dtype: int64

# %%
dataframe2.animal.count()
# Out:
# 22

# %%
dataframe2[['animal']].count()
# Out:
# animal    22
# dtype: int64

# %%
len(dataframe2[['animal']])
# Out:
# 22

# %%
dataframe2.water_need.sum()
# Out:
# 7650

# %%
dataframe2[['water_need']].sum()
# Out:
# water_need    7650
# dtype: int64

# %%
dataframe2[['water_need']].min()
# Out:
# water_need    80
# dtype: int64

# %%
dataframe2[['water_need']].max()
# Out:
# water_need    600
# dtype: int64

# %%
dataframe2[['water_need']].mean() #average water_need value
# Out:
# water_need    347.727273
# dtype: float64

# %%
dataframe2[['water_need']].median()
# Out:
# water_need    325.0
# dtype: float64

# %% [markdown]
# Groupby()

# %%
dataframe2.groupby('animal').sum()[['water_need']]
# Out:
#           water_need
# animal
# elephant        1650
# kangaroo        1250
# lion            1910
# tiger           1550
# zebra           1290

# %%
dataframe2.groupby('animal').sum()[['uniq_id']]
# Out:
#           uniq_id
# animal
# elephant     3006
# kangaroo     3063
# lion         4070
# tiger        5030
# zebra        7084

# %%
import pandas as pd
import numpy as np
#dataframe=pd.read_csv('pandas_tutorial_read.csv', sep=';')
dataframe=pd.read_csv('pandas_tutorial_read.csv', sep=';',names=['my_datatime','event','country','user_id','source','topic'])
dataframe
# Out:
#               my_datatime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
dataframe.groupby('source').count()
# Out:
#          my_datatime  event  country  user_id  topic
# source
# AdWords          500    500      500      500    500
# Reddit           949    949      949      949    949
# SEO              346    346      346      346    346

# %% [markdown]
# What’s the most frequent source in the dataframe?

# %%
dataframe.groupby('source').count()[['user_id']]
# Out:
#          user_id
# source
# AdWords      500
# Reddit       949
# SEO          346

# %% [markdown]
# what was the most frequent topic and source combination? Or in other words: which topic, from which source, brought the most views from country_2?

# %%
dataframe.groupby('country').count()
# Out:
#            my_datatime  event  user_id  source  topic
# country
# country_1           36     36       36      36     36
# country_2          462    462      462     462    462
# country_3           36     36       36      36     36
# country_4           81     81       81      81     81
# country_5          409    409      409     409    409
# country_6          245    245      245     245    245
# country_7          373    373      373     373    373
# country_8          153    153      153     153    153

# %%
dataframe[dataframe.country == 'country_2'].groupby(['topic','source']).count()
# Out:
#                        my_datatime  event  country  user_id
# topic         source
# Africa        AdWords           22     22       22       22
#               Reddit            88     88       88       88
#               SEO               15     15       15       15
# Asia          AdWords          146    146      146      146
#               Reddit           487    487      487      487
#               SEO               34     34       34       34
# Australia     AdWords           27     27       27       27
#               Reddit            72     72       72       72
#               SEO               22     22       22       22
# Europe        AdWords          187    187      187      187
#               Reddit           103    103      103      103
#               SEO               32     32       32       32
# North America AdWords           58     58       58       58
#               Reddit            92     92       92       92
# ...
