# %%
import nltk,csv,numpy 
from nltk import sent_tokenize, word_tokenize, pos_tag
reader = csv.reader(open('reviews.csv', 'r'), delimiter= ",")
tokenData = nltk.word_tokenize(str(reader))
print(tokenData)
# Out:
# ['<', '_csv.reader', 'object', 'at', '0x0000025711CD46C8', '>']

# %%
import codecs
import nltk
with codecs.open('reviews.csv', 'r',"utf-8") as f:
    for line in f:
        tweet = f.readlines()
        token_words=[]

        tokenized_sents = [word_tokenize(i) for i in tweet]
        for i in tokenized_sents[:500]:
            token_words.append(nltk.pos_tag(i))
token_words
# Out:
# [[('0,767,33', 'CD'),
#   (',', ','),
#   (',Absolutely', 'RB'),
#   ('wonderful', 'JJ'),
#   ('-', ':'),
#   ('silky', 'NN'),
#   ('and', 'CC'),
#   ('sexy', 'NN'),
#   ('and', 'CC'),
#   ('comfortable,4,1,0', 'NN'),
#   (',', ','),
#   ('Initmates', 'NNP'),
#   (',', ','),
#   ('Intimate', 'NNP'),
#   (',', ','),
#   ('Intimates', 'NNP')],
#  [('1,1080,34', 'CD'),
#   (',', ','),
#   (',', ','),
#   ("''", "''"),
#   ('Love', 'NNP'),
#   ('this', 'DT'),
#   ('dress', 'NN'),
#   ('!', '.'),
#   ('it', 'PRP'),
#   ("'s", 'VBZ'),
#   ('sooo', 'JJ'),
#   ('pretty', 'RB'),
#   ('.', '.'),
#   ('i', 'NN'),
#   ('happened', 'VBD'),
#   ('to', 'TO'),
#   ('find', 'VB'),
#   ('it', 'PRP'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('store', 'NN'),
#   (',', ','),
#   ('and', 'CC'),
#   ('i', 'JJ'),
#   ("'m", 'VBP'),
#   ('glad', 'JJ'),
#   ('i', 'NN'),
#   ('did', 'VBD'),
#   ('bc', 'NN'),
#   ('i', 'NN'),
#   ('never', 'RB'),
#   ('would', 'MD'),
#   ('have', 'VB'),
#   ('ordered', 'VBN'),
# ...

# %% [markdown]
# #word_tag_pairs = nltk.bigrams(token_words)
# #list(word_tag_pairs)
# adjective_count=[]
# for a in token_words:
#     if a == 'felt':
#         adjective_count.append(a)
# adjective_count
# #fdist = nltk.FreqDist(noun_preceders)
# #[tag for (tag, _) in fdist.most_common()]

# %%
adjective_count=[]
for word in token_words:
    #if word=='JJ':
    adjective_count.append(word)
    adjective_count
